# %% [markdown]
# ## Pandas
# 1. Introduction
# 2. Data Description
# 3. Creating a DataFrame
# 4. Data Cleaning
# 5. Dealing with Empty cell
# 6. Dealing with wrong data
# 7. Dealing with wrong data type
# 8. Dealing with duplicate data
# 9. Correlation
# 10. Conclusion

# %%
import pandas as pd

# %% [markdown]
# ### Create a data frame

# %%
df = pd.read_csv("Black_friday_sale.csv", header=0)
df.head(15)
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000004  P00128942      M  46-50           7             B
# 1   1000009  P00113442      M  26-35          17             C
# 2   1000010  P00288442      F  36-45           1             B
# 3   1000010  P00145342      F  36-45           1             B
# 4   1000011  P00053842      F  26-35           1             C
# 5   1000013  P00350442      M  46-50           1             C
# 6   1000013  P00155442      M  46-50           1             C
# 7   1000013   P0094542      M  46-50           1             C
# 8   1000015  P00161842      M  26-35           7             A
# 9   1000022  P00067942      M  18-25          15             A
# 10  1000026  P00046742      M  26-35           7             B
# 11  1000026  P00040042      M  26-35           7             B
# 12  1000026  P00196542      M  26-35           7             B
# 13  1000026  P00004542      M  26-35           7             B
# ...

# %%
df = pd.read_csv("Black_friday_sale.csv", index_col=0, header=0)
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 NaN
# 1000009                 5.0                 NaN
# ...

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
df.tail()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1006036                         4+               1                   8
# 1006036                         4+               1                   5
# 1006036                         4+               1                   1
# 1006037                         4+               0                  10
# 1006039                         4+               1                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1006036                 NaN                 NaN
# 1006036                 8.0                 NaN
# ...

# %% [markdown]
# ### Series

# %%
l = [12, 9, 8]
s1 = pd.Series(l)
print(s1)
# Out:
# 0    12
# 1     9
# 2     8
# dtype: int64

# %%
s1 = pd.Series(l, index = ["a", "b", "c"])
s1
# Out:
# a    12
# b     9
# c     8
# dtype: int64

# %%
d = {"a": 12, "b": 23, "c": 10}

# %%
s1 = pd.Series(d)
print(s1)
# Out:
# a    12
# b    23
# c    10
# dtype: int64

# %% [markdown]
# ### Create Data Frame Mannually

# %%
classes = pd.Series(["Mathematics", "Chemistry", "Physics", "History", "Geography", "German"])
grades = pd.Series([90, 54, 77, 22, 25])

df1 = pd.DataFrame({"Subjects": classes, "grades": grades})

# %%
df1.head()
# Out:
#       Subjects  grades
# 0  Mathematics    90.0
# 1    Chemistry    54.0
# 2      Physics    77.0
# 3      History    22.0
# 4    Geography    25.0

# %% [markdown]
# ##### without using dict

# %%
classes = ["Mathematics", "Chemistry", "Physics", "History", "Geography", "German"]
grades = [90, 54, 77, 22, 25]
df1 = pd.DataFrame([classes, grades])

# %%
df1.head()
# Out:
#              0          1        2        3          4       5
# 0  Mathematics  Chemistry  Physics  History  Geography  German
# 1           90         54       77       22         25    None

# %% [markdown]
# ##### with tuples

# %%
classes = ("Mathematics", "Chemistry", "Physics", "History", "Geography", "German")
grades = (90, 54, 77, 22, 25)
df1 = pd.DataFrame([classes, grades])

# %%
df1.head()
# Out:
#              0          1        2        3          4       5
# 0  Mathematics  Chemistry  Physics  History  Geography  German
# 1           90         54       77       22         25    None

# %% [markdown]
# ##### But correct way to used it is dict

# %% [markdown]
# ##### Check Version

# %%
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# #### Homework
# run following function
# f1.into()
# f1.tail()

# %%
df1.tail()
# Out:
#              0          1        2        3          4       5
# 0  Mathematics  Chemistry  Physics  History  Geography  German
# 1           90         54       77       22         25    None

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Bad data could be:
# Empty cells
# Data in wrong format
# Wrong data
# Duplication

# %%
df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0                 NaN
# 1000009                 5.0                 NaN
# ...

# %% [markdown]
# ###### Dealing with Empty cells

# %% [markdown]
# Mean, Mean is the most commonly used measure of central tendency. It actually represents the average of the given collection of data. It is applicable for both continuous and discret data.
# It is equal to the sum of all the values in the collection of data divided by the total number of values.
#
#
# Median : Generally median represent the mid-value of the given set of data when arranged in a particular order.
#
# If number of values or observation in the given data is odd, then the median is given by observation .
#
# (n+1/2)th
#
# If the given data set, the number of values or observations is even then the median is given by the average of observation.

# %% [markdown]
# #### Mode
# The most frequent number occuring in the data set is known as the mode.

# %%
new_df = df.dropna()

# %%
new_df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000011  P00053842      F  26-35           1             C
# 1000013  P00350442      M  46-50           1             C
# 1000013  P00155442      M  46-50           1             C
# 1000013   P0094542      M  46-50           1             C
# 1000015  P00161842      M  26-35           7             A
# ...            ...    ...    ...         ...           ...
# 1006023  P00262242      M  26-35           0             C
# 1006026  P00110742      M  36-45           6             C
# 1006030  P00129842      M  26-35          17             C
# 1006033  P00127642      M  51-55          13             B
# 1006036  P00031842      F  26-35          15             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000011                          1               0                   4
# 1000013                          3               1                   2
# ...

# %%
df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       161255.000000
# mean        8.085407        0.410070            5.276542            9.849586
# std         6.521146        0.491847            3.736380            5.094943
# min         0.000000        0.000000            1.000000            2.000000
# 25%         2.000000        0.000000            1.000000            5.000000
# 50%         7.000000        0.000000            5.000000            9.000000
# 75%        14.000000        1.000000            8.000000           15.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
new_df.describe()
# Out:
#          Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  71037.000000    71037.000000        71037.000000        71037.000000
# mean       8.219801        0.402002            2.725185            6.882287
# std        6.482756        0.490306            2.564070            4.510544
# min        0.000000        0.000000            1.000000            2.000000
# 25%        3.000000        0.000000            1.000000            2.000000
# 50%        7.000000        0.000000            1.000000            6.000000
# 75%       14.000000        1.000000            4.000000           10.000000
# max       20.000000        1.000000           15.000000           16.000000
#
#        Product_Category_3
# count        71037.000000
# mean            12.669454
# std              4.125944
# min              3.000000
# 25%              9.000000
# 50%             14.000000
# 75%             16.000000
# max             18.000000

# %%
# replace NA value with 0
new_df = df.fillna(0)

# %%
new_df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
new_df.describe()
# Out:
#           Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# count  233599.000000   233599.000000       233599.000000       233599.000000
# mean        8.085407        0.410070            5.276542            6.799237
# std         6.521146        0.491847            3.736380            6.217668
# min         0.000000        0.000000            1.000000            0.000000
# 25%         2.000000        0.000000            1.000000            0.000000
# 50%         7.000000        0.000000            5.000000            5.000000
# 75%        14.000000        1.000000            8.000000           14.000000
# max        20.000000        1.000000           18.000000           18.000000
#
#        Product_Category_3
# count       233599.000000
# mean             3.852756
# std              6.256634
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              8.000000
# max             18.000000

# %%
mean = df["Product_Category_3"].mean()

# %%
new_df = df.fillna(mean)

# %%
new_df.head()
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# 1000010                         4+               1                   5
# 1000010                         4+               1                   4
# 1000011                          1               0                   4
#
#          Product_Category_2  Product_Category_3
# User_ID
# 1000004                11.0           12.669454
# 1000009                 5.0           12.669454
# ...

# %%
median = df["Product_Category_3"].median()
median
# Out:
# 14.0

# %%
new_df = df.fillna(median)

# %%
new_df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...

# %%
# mode
mode =  df["Product_Category_3"].mode()
new_df = df.fillna(mode)
new_df
# Out:
#         Product_ID Gender    Age  Occupation City_Category  \
# User_ID
# 1000004  P00128942      M  46-50           7             B
# 1000009  P00113442      M  26-35          17             C
# 1000010  P00288442      F  36-45           1             B
# 1000010  P00145342      F  36-45           1             B
# 1000011  P00053842      F  26-35           1             C
# ...            ...    ...    ...         ...           ...
# 1006036  P00118942      F  26-35          15             B
# 1006036  P00254642      F  26-35          15             B
# 1006036  P00031842      F  26-35          15             B
# 1006037  P00124742      F  46-50           1             C
# 1006039  P00316642      F  46-50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# User_ID
# 1000004                          2               1                   1
# 1000009                          0               0                   3
# ...
